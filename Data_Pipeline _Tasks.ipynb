# %%
from prefect import task, Flow

# %%
import pandas as pd
import numpy as np ##to work with arrays

# %%
df=pd.read_csv("S:\\ML_AI_DS\\\MY_TASKS\\sample_dataset.csv")

# %%
df.head(5)
# Out:
#    S.No  order date   time                                       product_info
# 0     1  22/07/2021  15:45  [{\n    "id": 1,\n    "product_id": "33-745-50...
# 1     2  21/10/2021  20:37  [{\n    "id": 3,\n    "product_id": "48-081-02...
# 2     3  21/04/2021  15:15  [{\n    "id": 6,\n    "product_id": "31-992-73...
# 3     4  20/10/2021  05:35  [{\n    "id": 7,\n    "product_id": "99-904-84...
# 4     5  23/05/2021  14:04  [{\n    "id": 10,\n    "product_id": "37-943-6...

# %%
df.tail(5)
# Out:
#     S.No  order date   time                                       product_info
# 24    25  19/08/2021  15:46  [{\n    "id": 7,\n    "product_id": "99-904-84...
# 25    26  31/10/2021  21:33  [{\n    "id": 1,\n    "product_id": "33-745-50...
# 26    27  08/12/2021  10:05  [{\n    "id": 3,\n    "product_id": "48-081-02...
# 27    28  20/10/2021  09:36  [{\n    "id": 6,\n    "product_id": "31-992-73...
# 28    29  04/05/2021  10:34  [{\n    "id": 7,\n    "product_id": "99-904-84...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   order date    29 non-null     object
#  2   time          29 non-null     object
#  3   product_info  29 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.0+ KB

# %%
df.shape
# Out:
# (29, 4)

# %%
df1=df['product_info']

# %%
df1.head(5)
# Out:
# 0    [{\n    "id": 1,\n    "product_id": "33-745-50...
# 1    [{\n    "id": 3,\n    "product_id": "48-081-02...
# 2    [{\n    "id": 6,\n    "product_id": "31-992-73...
# 3    [{\n    "id": 7,\n    "product_id": "99-904-84...
# 4    [{\n    "id": 10,\n    "product_id": "37-943-6...
# Name: product_info, dtype: object

# %%
df2=df['order date']

# %%
df2.head(5)
# Out:
# 0    22/07/2021
# 1    21/10/2021
# 2    21/04/2021
# 3    20/10/2021
# 4    23/05/2021
# Name: order date, dtype: object

# %%
df2_neat = df.rename(columns = {'order date': 'date'}, inplace = False)

# %%
df2_neat.head(5)
# Out:
#    S.No        date   time                                       product_info
# 0     1  22/07/2021  15:45  [{\n    "id": 1,\n    "product_id": "33-745-50...
# 1     2  21/10/2021  20:37  [{\n    "id": 3,\n    "product_id": "48-081-02...
# 2     3  21/04/2021  15:15  [{\n    "id": 6,\n    "product_id": "31-992-73...
# 3     4  20/10/2021  05:35  [{\n    "id": 7,\n    "product_id": "99-904-84...
# 4     5  23/05/2021  14:04  [{\n    "id": 10,\n    "product_id": "37-943-6...

# %%
#Convert "order date" Dtype from Object to datetime
pd.to_datetime(df2_neat.date)
# Out:
# 0    2021-07-22
# 1    2021-10-21
# 2    2021-04-21
# 3    2021-10-20
# 4    2021-05-23
# 5    2021-09-02
# 6    2021-09-10
# 7    2021-10-05
# 8    2021-11-23
# 9    2021-12-23
# 10   2021-02-28
# 11   2021-06-22
# 12   2021-07-07
# 13   2021-07-07
# 14   2021-03-26
# 15   2022-09-01
# 16   2021-06-28
# 17   2021-11-26
# 18   2021-04-05
# 19   2021-06-16
# 20   2022-01-01
# 21   2021-09-14
# 22   2021-06-04
# 23   2021-07-07
# 24   2021-08-19
# 25   2021-10-31
# 26   2021-08-12
# 27   2021-10-20
# 28   2021-04-05
# Name: date, dtype: datetime64[ns]

# %%
df2_neat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     object
#  2   time          29 non-null     object
#  3   product_info  29 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.0+ KB

# %%
df2_neat['date']=pd.to_datetime(df2_neat.date) #Assign

# %%
df2_neat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   time          29 non-null     object
#  3   product_info  29 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.0+ KB

# %%
df2_neat['date_new'] = df2_neat['date'].dt.strftime('%B-%Y')

# %%
df2_neat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   time          29 non-null     object
#  3   product_info  29 non-null     object
#  4   date_new      29 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
df2_neat.head(5)
# Out:
#    S.No       date   time                                       product_info  \
# 0     1 2021-07-22  15:45  [{\n    "id": 1,\n    "product_id": "33-745-50...
# 1     2 2021-10-21  20:37  [{\n    "id": 3,\n    "product_id": "48-081-02...
# 2     3 2021-04-21  15:15  [{\n    "id": 6,\n    "product_id": "31-992-73...
# 3     4 2021-10-20  05:35  [{\n    "id": 7,\n    "product_id": "99-904-84...
# 4     5 2021-05-23  14:04  [{\n    "id": 10,\n    "product_id": "37-943-6...
#
#        date_new
# 0     July-2021
# 1  October-2021
# 2    April-2021
# 3  October-2021
# 4      May-2021

# %%
df2_neat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   time          29 non-null     object
#  3   product_info  29 non-null     object
#  4   date_new      29 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
pd.to_datetime(df3.time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-32844d139ef5> in <module>
# ----> 1 pd.to_datetime(df3.time)
#
# NameError: name 'df3' is not defined

# %%
df2_neat['time']=pd.to_datetime(df2_neat.time)

# %%
df2_neat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   time          29 non-null     datetime64[ns]
#  3   product_info  29 non-null     object
#  4   date_new      29 non-null     object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 1.3+ KB

# %%
df2_neat['hour'] = pd.to_datetime(df2_neat['time'], format='%H:%M:%S').dt.hour

# %%
df2_neat.head(5)
# Out:
#    S.No       date                time  \
# 0     1 2021-07-22 2022-02-02 15:45:00
# 1     2 2021-10-21 2022-02-02 20:37:00
# 2     3 2021-04-21 2022-02-02 15:15:00
# 3     4 2021-10-20 2022-02-02 05:35:00
# 4     5 2021-05-23 2022-02-02 14:04:00
#
#                                         product_info      date_new  hour
# 0  [{\n    "id": 1,\n    "product_id": "33-745-50...     July-2021    15
# 1  [{\n    "id": 3,\n    "product_id": "48-081-02...  October-2021    20
# 2  [{\n    "id": 6,\n    "product_id": "31-992-73...    April-2021    15
# 3  [{\n    "id": 7,\n    "product_id": "99-904-84...  October-2021     5
# 4  [{\n    "id": 10,\n    "product_id": "37-943-6...      May-2021    14

# %% [markdown]
# ### Task 2

# %%
df4=df2_neat['product_info']

# %%
df4.head(5)
# Out:
# 0    [{\n    "id": 1,\n    "product_id": "33-745-50...
# 1    [{\n    "id": 3,\n    "product_id": "48-081-02...
# 2    [{\n    "id": 6,\n    "product_id": "31-992-73...
# 3    [{\n    "id": 7,\n    "product_id": "99-904-84...
# 4    [{\n    "id": 10,\n    "product_id": "37-943-6...
# Name: product_info, dtype: object

# %%
pd.set_option("display.max_colwidth", None)

# %%
df4.head(4)
# Out:
# 0                                                                                                       [{\n    "id": 1,\n    "product_id": "33-745-5073",\n    "product name": "Betonica Rosmarinus",\n    "qty": 2,\n    "price": 8\n  }, {\n    "id": 2,\n    "product_id": "70-530-5687",\n    "product name": "Olive Oil and Lemon Antibacterial Foaming Hand Wash",\n    "qty": 2,\n    "price": 26\n  }]
# 1           [{\n    "id": 3,\n    "product_id": "48-081-0206",\n    "product name": "Fycompa",\n    "qty": 3,\n    "price": 91\n  }, {\n    "id": 4,\n    "product_id": "39-335-0082",\n    "product name": "Diphenhydramine Hydrochloride",\n    "qty": 9,\n    "price": 89\n  }, {\n    "id": 5,\n    "product_id": "84-589-2764",\n    "product name": "Lansoprazole",\n    "qty": 5,\n    "price": 55\n  }]
# ...

# %%
import json
from pandas import Series

# %%
json_cols = [0]

for column in json_cols:

    c_load = df4[column].apply(json.loads)
    c_list = list(c_load)
    c_dat = json.dumps(c_list)

    df4 = df4.join(pd.read_json(c_dat))
    df4 = df4.drop(column , axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-05e26fe3f536> in <module>
#       3 for column in json_cols:
#       4
# ----> 5     c_load = df4[column].apply(json.loads)
#       6     c_list = list(c_load)
#       7     c_dat = json.dumps(c_list)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
df2_neat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   time          29 non-null     datetime64[ns]
#  3   product_info  29 non-null     object
#  4   date_new      29 non-null     object
#  5   hour          29 non-null     int64
# dtypes: datetime64[ns](2), int64(2), object(2)
# memory usage: 1.5+ KB

# %%
df5=df2_neat[["S.No","date","product_info"]]

# %%
df5.head(3)
# Out:
#    S.No       date  \
# 0     1 2021-07-22
# 1     2 2021-10-21
# 2     3 2021-04-21
#
#                                                                                                                                                                                                                                                                                                                                                                                           product_info
# 0                                                                                              [{\n    "id": 1,\n    "product_id": "33-745-5073",\n    "product name": "Betonica Rosmarinus",\n    "qty": 2,\n    "price": 8\n  }, {\n    "id": 2,\n    "product_id": "70-530-5687",\n    "product name": "Olive Oil and Lemon Antibacterial Foaming Hand Wash",\n    "qty": 2,\n    "price": 26\n  }]
# ...

# %%
x=pd.DataFrame(df5.product_info.values.tolist())['product_info']
pd.json_normalize(x).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-991e11d12ecf> in <module>
# ----> 1 x=pd.DataFrame(df5.product_info.values.tolist())['product_info']
#       2 pd.json_normalize(x).head()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
# ...

# %%
data=json.loads('product_info')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-47-c502e698a783> in <module>
# ----> 1 data=json.loads('product_info')
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
import findspark
findspark.init()

# %%
import pyspark.sql.functions as F
import pyspark as ps
from pyspark import SQLContext

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   product_info  29 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 824.0+ bytes

# %%
spark = ps.sql.SparkSession.builder \
    .master('local[2]') \
    .appName('spark-ml') \
    .getOrCreate()

sc = spark.sparkContext

# %%
##Convert Json Object into Json String
df5['product_info'] = df5['product_info'].astype('|S')
# Out:
# C:\Users\lucif\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          29 non-null     int64
#  1   date          29 non-null     datetime64[ns]
#  2   product_info  29 non-null     |S377
# dtypes: bytes3016(1), datetime64[ns](1), int64(1)
# memory usage: 11.3 KB

# %%
df6 = pd.read_json('product_info.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-242b857dc668> in <module>
# ----> 1 df6 = pd.read_json('product_info.json', lines=True)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
stdf = df5['product_info'].apply(json.loads)
pd.DataFrame(stdf.tolist())
# Out:
#                                                                                                                       0  \
# 0                   {'id': 1, 'product_id': '33-745-5073', 'product name': 'Betonica Rosmarinus', 'qty': 2, 'price': 8}
# 1                              {'id': 3, 'product_id': '48-081-0206', 'product name': 'Fycompa', 'qty': 3, 'price': 91}
# 2                      {'id': 6, 'product_id': '31-992-7300', 'product name': 'LBEL HYDRATESS', 'qty': 10, 'price': 48}
# 3   {'id': 7, 'product_id': '99-904-8455', 'product name': 'CELLULAR RADIANCE SUNSCREEN SPF 30', 'qty': 7, 'price': 37}
# 4   {'id': 10, 'product_id': '37-943-6902', 'product name': 'Assured Extra Strength Cold n hot', 'qty': 11, 'price': 1}
# 5                  {'id': 1, 'product_id': '33-745-5073', 'product name': 'Betonica Rosmarinus', 'qty': 10, 'price': 8}
# 6                              {'id': 3, 'product_id': '48-081-0206', 'product name': 'Fycompa', 'qty': 3, 'price': 91}
# ...

# %%
df5.join(df5['product_info'].apply(json.loads).apply(pd.Series))
# Out:
#     S.No       date  \
# 0      1 2021-07-22
# 1      2 2021-10-21
# 2      3 2021-04-21
# 3      4 2021-10-20
# 4      5 2021-05-23
# 5      6 2021-09-02
# 6      7 2021-09-10
# 7      8 2021-10-05
# 8      9 2021-11-23
# 9     10 2021-12-23
# 10    11 2021-02-28
# 11    12 2021-06-22
# 12    13 2021-07-07
# 13    14 2021-07-07
# 14    15 2021-03-26
# 15    16 2022-09-01
# 16    17 2021-06-28
# 17    18 2021-11-26
# 18    19 2021-04-05
# 19    20 2021-06-16
# 20    21 2022-01-01
# 21    22 2021-09-14
# 22    23 2021-06-04
# 23    24 2021-07-07
# 24    25 2021-08-19
# 25    26 2021-10-31
# 26    27 2021-08-12
# 27    28 2021-10-20
# 28    29 2021-04-05
#
# ...

# %%
df5.tail(7)
# Out:
#     S.No       date  \
# 22    23 2021-06-04
# 23    24 2021-07-07
# 24    25 2021-08-19
# 25    26 2021-10-31
# 26    27 2021-08-12
# 27    28 2021-10-20
# 28    29 2021-04-05
#
#                                                                                                                                                                                                                                                                                                                                                                                                      product_info
# 22         b'[{\n    "id": 3,\n    "product_id": "48-081-0206",\n    "product name": "Fycompa",\n    "qty": 3,\n    "price": 91\n  }, {\n    "id": 4,\n    "product_id": "39-335-0082",\n    "product name": "Diphenhydramine Hydrochloride",\n    "qty": 4,\n    "price": 89\n  }, {\n    "id": 5,\n    "product_id": "84-589-2764",\n    "product name": "Lansoprazole",\n    "qty": 5,\n    "price": 55\n  }]'
# ...

# %%
stdf1 = stdf["0","1"].apply(json.loads)
pd.DataFrame(stdf.tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-6c7b1520f200> in <module>
# ----> 1 stdf1 = stdf["0","1"].apply(json.loads)
#       2 pd.DataFrame(stdf.tolist())
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in __getitem__(self, key)
#     875             return self._get_values(key)
#     876
# --> 877         return self._get_with(key)
#     878
#     879     def _get_with(self, key):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _get_with(self, key)
#     890             )
#     891         elif isinstance(key, tuple):
# --> 892             return self._get_values_tuple(key)
#     893
#     894         elif not is_list_like(key):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#     925
# ...

# %%
data=pd.read_csv("S:\\ML_AI_DS\\MY_TASKS\\gmv_data.csv")

# %%
data.head()
# Out:
#    SNo        Date   GMV
# 0    1  04/12/2021  2518
# 1    2  18/05/2021  3483
# 2    3  16/09/2021  1664
# 3    4  15/04/2021  1720
# 4    5  27/11/2021  1515

# %%
data.tail()
# Out:
#     SNo        Date   GMV
# 24   25  24/03/2021  5162
# 25   26  08/06/2021  3087
# 26   27  21/04/2021  7475
# 27   28  27/08/2021  8308
# 28   29  16/08/2021  1281

# %%
stdf=df2_neat[["S.No","date","product_info","time","date_new","hour"]]

# %%
stdf.head()
# Out:
#    S.No       date  \
# 0     1 2021-07-22
# 1     2 2021-10-21
# 2     3 2021-04-21
# 3     4 2021-10-20
# 4     5 2021-05-23
#
#                                                                                                                                                                                                                                                                                                                                                                                                  product_info  \
# 0                                                                                                     [{\n    "id": 1,\n    "product_id": "33-745-5073",\n    "product name": "Betonica Rosmarinus",\n    "qty": 2,\n    "price": 8\n  }, {\n    "id": 2,\n    "product_id": "70-530-5687",\n    "product name": "Olive Oil and Lemon Antibacterial Foaming Hand Wash",\n    "qty": 2,\n    "price": 26\n  }]
# ...

# %%
final_dataset=pd.merge(stdf,data)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-71-4b7b0377cf71> in <module>
# ----> 1 final_dataset=pd.merge(stdf,data)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ...

# %%
final_dataset=pd.merge(stdf, data, left_index=True, right_index=True)

# %%
final_dataset.head()
# Out:
#    S.No       date  \
# 0     1 2021-07-22
# 1     2 2021-10-21
# 2     3 2021-04-21
# 3     4 2021-10-20
# 4     5 2021-05-23
#
#                                                                                                                                                                                                                                                                                                                                                                                                  product_info  \
# 0                                                                                                     [{\n    "id": 1,\n    "product_id": "33-745-5073",\n    "product name": "Betonica Rosmarinus",\n    "qty": 2,\n    "price": 8\n  }, {\n    "id": 2,\n    "product_id": "70-530-5687",\n    "product name": "Olive Oil and Lemon Antibacterial Foaming Hand Wash",\n    "qty": 2,\n    "price": 26\n  }]
# ...

# %%
final_dataset.to_csv(r"S:\\ML_AI_DS\MY_TASKS\\final_dataset.csv")
